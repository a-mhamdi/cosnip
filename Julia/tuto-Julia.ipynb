# %%
]up
# Out:
#     Updating registry at `~/.julia/registries/General`
#    Installed IterTools ──────────────────────── v1.4.0
#    Installed Setfield ───────────────────────── v0.8.2
#    Installed SLEEFPirates ───────────────────── v0.6.31
#    Installed JSON ───────────────────────────── v0.21.3
#    Installed Polynomials ────────────────────── v2.0.25
#    Installed ControlSystems ─────────────────── v0.12.5
#    Installed StaticArrays ───────────────────── v1.4.1
#    Installed Plots ──────────────────────────── v1.26.0
#    Installed HostCPUFeatures ────────────────── v0.1.7
#    Installed HTTP ───────────────────────────── v0.9.17
#    Installed MutableArithmetics ─────────────── v1.0.0
#    Installed ForwardDiff ────────────────────── v0.10.25
#    Installed RelocatableFolders ─────────────── v0.1.3
#    Installed PolyesterWeave ─────────────────── v0.1.5
#    Installed StructArrays ───────────────────── v0.6.5
#    Installed Calculus ───────────────────────── v0.5.1
# ...

# %% [markdown]
# Evaluate some os commands

# %%
;ls
# Out:
# Julia.png
# README.md
# sys-ctrl.ipynb
# sys-ctrl.jl
# tuto-Julia.ipynb

# %% [markdown]
# Seek help on a particular function. We just use the `?` mark

# %%
?cos
# Out:
# search: cos cosh cosd cosc cospi acos acosh acosd sincos sincosd sincospi const
#   cos(x)
#
#   Compute cosine of x, where x is in radians.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   cos(A::AbstractMatrix)
#
#   Compute the matrix cosine of a square matrix A.
#
#   If A is symmetric or Hermitian, its eigendecomposition (eigen) is used to
#   compute the cosine. Otherwise, the cosine is determined by calling exp.
#
#   Examples
#   ≡≡≡≡≡≡≡≡≡≡
#
#   julia> cos(fill(1.0, (2,2)))
#   2×2 Matrix{Float64}:
#     0.291927  -0.708073
#    -0.708073   0.291927

# %%
print("Hello")
print(' ')
print("World")
# Out:
# Hello World

# %%
println("Hello")
println("World")
# Out:
# Hello
# World
